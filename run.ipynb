# %%
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'ViGLUE/requirements.txt'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1965261682.py in <cell line: 0>()
# ----> 1 nvidia-smi
#
# NameError: name 'nvidia' is not defined
